# %%
import numpy
from matplotlib import pylab
fin_eq14=numpy.load("/rds/project/bn204/rds-bn204-asterics/jck42/BiSpectrum/Binned_Data/EQ14/XX/output_bin.npz")
fin_eq28=numpy.load("/rds/project/bn204/rds-bn204-asterics/jck42/BiSpectrum/Binned_Data/EQ28/XX/output_bin.npz")
fin_linew=numpy.load("/rds/project/bn204/rds-bn204-asterics/jck42/BiSpectrum/Binned_Data/LinEW/XX/output_bin.npz")
fin_linp30=numpy.load("/rds/project/bn204/rds-bn204-asterics/jck42/BiSpectrum/Binned_Data/Linp30/XX/output_bin.npz")
fin_linm30=numpy.load("/rds/project/bn204/rds-bn204-asterics/jck42/BiSpectrum/Binned_Data/Linm30/XX/output_bin.npz")
dd_eq14 = fin_eq14['closures']
dd_eq28 = fin_eq28['closures']
dd_linew = fin_linew['closures']
dd_linp30 = fin_linp30['closures']
dd_linm30 = fin_linm30['closures']

# %%
# %run procps.py
# %run plotprelude.py

# %%
#Medians for Equilateral 14m triads
pp_eq14_1=mdays(dd_eq14[:,0:8], 1)
pp_eq14_2=mdays(dd_eq14[:,8:], 1)
pp_eq14=numpy.concatenate((pp_eq14_1, pp_eq14_2), axis=1)       

#Medians for ever other Equilateral 28m triads
pp_eq28_1=mdays(dd_eq28[:,0:8], 1)
pp_eq28_2=mdays(dd_eq28[:,8:], 1)
pp_eq28=numpy.concatenate((pp_eq28_1, pp_eq28_2), axis=1)  

#Medians for every other Linear East-West Triads
pp_linew_1=mdays(dd_linew[:,0:8], 1)
pp_linew_2=mdays(dd_linew[:,8:], 1)
pp_linew=numpy.concatenate((pp_linew_1, pp_linew_2), axis=1)

#Medians for every other Linear 30 degree Triads
pp_linp30_1=mdays(dd_linp30[:,0:8], 1)
pp_linp30_2=mdays(dd_linp30[:,8:], 1)
pp_linp30=numpy.concatenate((pp_linp30_1, pp_linp30_2), axis=1)

#Medians for every other Linear 180-30 degree Triads
pp_linm30_1=mdays(dd_linm30[:,0:8], 1)
pp_linm30_2=mdays(dd_linm30[:,8:], 1)
pp_linm30=numpy.concatenate((pp_linm30_1, pp_linm30_2), axis=1)

# %%
x1=psXmedCTimCTriR(numpy.exp(1j*(pp_eq14[150:250,:,:,120:380])),
                       window="hamming")
pp_ps(x1)
x1=psXmedCTimCTriR(numpy.exp(1j*(pp_eq28[150:250,:,:,120:380])),
                       window="hamming")
pp_ps(x1)
x1=psXmedCTimCTriR(numpy.exp(1j*(pp_linew[150:250,:,:,120:380])),
                       window="hamming")
pp_ps(x1)
x1=psXmedCTimCTriR(numpy.exp(1j*(pp_linp30[150:250,:,:,120:380])),
                       window="hamming")
pp_ps(x1)
x1=psXmedCTimCTriR(numpy.exp(1j*(pp_linm30[150:250,:,:,120:380])),
                       window="hamming")
pp_ps(x1)
